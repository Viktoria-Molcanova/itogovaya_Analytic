# %%
# @title Аналитика ответы на вопросы
from prettytable import PrettyTable

myTable = PrettyTable(["Вопрос", "Ответ"])
myTable.align = 'l'
myTable.add_row(["1. Из каких регионов больше всего заявок", "1. Краснодарский край Ставропольский край Ростовская область Москва."])
myTable.add_row(["2. Какой средний процент отказов (Bounce) ", "2. 0,23%"])
myTable.add_row(["3. С каких устройств чаще заходят на сайты", "3. Мобильные устройства",])
myTable.add_row(["4. Какие источники наиболее конвертируемые ", "4. Яндекс,сайт дилера", ])
myTable.add_row(["5. Рассчитайте ROMI", "5. 7,26"])
myTable.add_row(["6. Посчитайте выручку в рублях только по долларовым позициям ", "6. 1,63 млрд",])
myTable.add_row(["7. Определите, какой источник трафика наиболее выгоден для компании по текущим данным ", "7. brontp.yandex.ru",])
myTable.add_row(["8. Ответьте на вопрос: каких показателей не хватает, чтобы посчитать чистую прибыль? ", "8. Понимания  постоянных расходов и стоимости автомобиля ",])
myTable.add_row(["9. Сделать прогноз до конца февраля по количеству конверсий на каждый день ", "9. Сделано в визуализации",])
myTable.add_row(["10. Какая будет выручка за первый квартал, если средняя стоимость авто останется неизменной, а продажи будут пропорциональны текущим данным? ", "10. 38,61 млрд",])
print(myTable)
# Out:
# +-----------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------+
# | Вопрос                                                                                                                                        | Ответ                                                                |
# +-----------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------+
# | 1. Из каких регионов больше всего заявок                                                                                                      | 1. Краснодарский край Ставропольский край Ростовская область Москва. |
# ...
